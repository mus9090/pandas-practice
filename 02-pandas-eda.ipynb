# %%
import pandas as pd
superstore = pd.read_csv("./data/superstore.csv", encoding="latin1")
superstore.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# EDA Questions

# %% [markdown]
# Q1 : Find all orders where sales > 500

# %%
superstore[superstore["Sales"]>500]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 7          8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 10        11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 11        12  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9931    9932  CA-2015-104948  11/13/2015  11/17/2015  Standard Class
# 9942    9943  CA-2014-143371  12/28/2014    1/3/2015  Standard Class
# 9947    9948  CA-2017-121559    6/1/2017    6/3/2017    Second Class
# 9948    9949  CA-2017-121559    6/1/2017    6/3/2017    Second Class
# 9968    9969  CA-2017-153871  12/11/2017  12/17/2017  Standard Class
#
#      Customer ID    Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# Q2 : Find all orders where Category = Technology and Profit > 100

# %%
superstore[(superstore["Category"]=="Technology")&(superstore["Profit"]>100)]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 35        36  CA-2016-117590   12/8/2016  12/10/2016     First Class
# 54        55  CA-2016-105816  12/11/2016  12/17/2016  Standard Class
# 147      148  CA-2016-114489   12/5/2016   12/9/2016  Standard Class
# 159      160  CA-2016-114104  11/20/2016  11/24/2016  Standard Class
# 182      183  CA-2014-158274  11/19/2014  11/24/2014    Second Class
# ...      ...             ...         ...         ...             ...
# 9727    9728  CA-2017-167395   12/2/2017   12/4/2017     First Class
# 9780    9781  CA-2016-153178   9/14/2016   9/18/2016  Standard Class
# 9833    9834  CA-2017-130302   9/14/2017   9/19/2017  Standard Class
# 9839    9840  US-2016-125402   9/25/2016   10/1/2016  Standard Class
# 9929    9930  CA-2016-129630    9/4/2016    9/4/2016        Same Day
#
#      Customer ID   Customer Name      Segment        Country           City  \
# ...
